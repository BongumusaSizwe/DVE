# %%
import pandas as pd
import seaborn as sns
import numpy as np
sns.set_theme(style="white")

import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %% [markdown]
# ## Attribute Information:
#
# ### Classes
# 19 Classes:
# - diaporthe-stem-canker,
# - charcoal-rot,
# - rhizoctonia-root-rot,
# - phytophthora-rot,
# - brown-stem-rot,
# - powdery-mildew,
# - downy-mildew,
# - brown-spot,
# - bacterial-blight,
# - bacterial-pustule,
# - purple-seed-stain,
# - anthracnose,
# - phyllosticta-leaf-spot,
# - alternarialeaf-spot,
# - frog-eye-leaf-spot,
# - diaporthe-pod-&-stem-blight,
# - cyst-nematode,
# - 2-4-d-injury,
# - herbicide-injury.
#
# ### Features
# 1. date: april,may,june,july,august,september,october,?.
# 2. plant-stand: normal,lt-normal,?.
# 3. precip: lt-norm,norm,gt-norm,?.
# 4. temp: lt-norm,norm,gt-norm,?.
# 5. hail: yes,no,?.
# 6. crop-hist: diff-lst-year,same-lst-yr,same-lst-two-yrs,same-lst-sev-yrs,?.
# 7. area-damaged: scattered,low-areas,upper-areas,whole-field,?.
# 8. severity: minor,pot-severe,severe,?.
# 9. seed-tmt: none,fungicide,other,?.
# 10. germination: 90-100%,80-89%,lt-80%,?.
# 11. plant-growth: norm,abnorm,?.
# 12. leaves: norm,abnorm.
# 13. leafspots-halo: absent,yellow-halos,no-yellow-halos,?.
# 14. leafspots-marg: w-s-marg,no-w-s-marg,dna,?.
# 15. leafspot-size: lt-1/8,gt-1/8,dna,?.
# 16. leaf-shread: absent,present,?.
# 17. leaf-malf: absent,present,?.
# 18. leaf-mild: absent,upper-surf,lower-surf,?.
# 19. stem: norm,abnorm,?.
# 20. lodging: yes,no,?.
# 21. stem-cankers: absent,below-soil,above-soil,above-sec-nde,?.
# 22. canker-lesion: dna,brown,dk-brown-blk,tan,?.
# 23. fruiting-bodies: absent,present,?.
# 24. external decay: absent,firm-and-dry,watery,?.
# 25. mycelium: absent,present,?.
# 26. int-discolor: none,brown,black,?.
# 27. sclerotia: absent,present,?.
# 28. fruit-pods: norm,diseased,few-present,dna,?.
# 29. fruit spots: absent,colored,brown-w/blk-specks,distort,dna,?.
# 30. seed: norm,abnorm,?.
# 31. mold-growth: absent,present,?.
# 32. seed-discolor: absent,present,?.
# 33. seed-size: norm,lt-norm,?.
# 34. shriveling: absent,present,?.
# 35. roots: norm,rotted,galls-cysts,?.

# %%
columns = ['class', 'date', 'plant-stand', 'precip', 'temp', 'hail', 'crop-hist', \
           'area-damaged', 'severity', 'seed-tmt', 'germination', 'plant-growth', \
          'leaves', 'leafspots-halo', 'leafspots-marg', 'leafspot-size', 'leaf-shread', \
           'leaf-malf', 'leaf-mild', 'stem', 'lodging', 'stem-cankers', 'canker-lesion',\
          'fruiting-bodies', 'external decay', 'mycelium', 'int-discolor', 'sclerotia',\
          'fruit-pods', 'fruit spots', 'seed', 'mold-growth', 'seed-discolor', 'seed-size',\
          'shriveling', 'roots']
df = pd.read_csv('data/soybeans/soybean-large.data', names=columns)

# %%
df.head()
# Out:
#                    class date plant-stand precip temp hail crop-hist  \
# 0  diaporthe-stem-canker    6           0      2    1    0         1
# 1  diaporthe-stem-canker    4           0      2    1    0         2
# 2  diaporthe-stem-canker    3           0      2    1    0         1
# 3  diaporthe-stem-canker    3           0      2    1    0         1
# 4  diaporthe-stem-canker    6           0      2    1    0         2
#
#   area-damaged severity seed-tmt  ... int-discolor sclerotia  fruit-pods  \
# 0            1        1        0  ...            0         0           0
# 1            0        2        1  ...            0         0           0
# 2            0        2        1  ...            0         0           0
# 3            0        2        0  ...            0         0           0
# 4            0        1        0  ...            0         0           0
#
#   fruit spots seed mold-growth seed-discolor seed-size shriveling roots
# 0           4    0           0             0         0          0     0
# 1           4    0           0             0         0          0     0
# 2           4    0           0             0         0          0     0
# 3           4    0           0             0         0          0     0
# 4           4    0           0             0         0          0     0
#
# [5 rows x 36 columns]

# %% [markdown]
# Notice how the values are all integers or "?".  The integers relate to the values gives in the attribute descriptions.
# So, for example, date value of 0 corresponds to April, roots value of 1 corresponds to "rotted".
#
# If you find it useful, you can create a mapping from the integer to the string.

# %%
def create_dict(vals):
    tmp_dict = {k: v for k, v in enumerate(vals.strip().split(',')) if v != '?'}
    tmp_dict['?'] = None
    return tmp_dict

maps = {
    'date': create_dict('april,may,june,july,august,september,october,?'),
    'plant-stand': create_dict('normal,lt-normal,?'),
    'precip': create_dict('lt-norm,norm,gt-norm,?'),
    'temp': create_dict('lt-norm,norm,gt-norm,?'),
    'hail': create_dict('yes,no,?'),
    'crop-hist': create_dict('diff-lst-year,same-lst-yr,same-lst-two-yrs,same-lst-sev-yrs,?'),
    'area-damaged': create_dict('scattered,low-areas,upper-areas,whole-field,?'),
    'severity': create_dict('minor,pot-severe,severe,?'),
    'seed-tmt': create_dict('none,fungicide,other,?'),
    'germination': create_dict('90-100%,80-89%,lt-80%,?'),
    'plant-growth': create_dict('norm,abnorm,?'),
    'leaves': create_dict('norm,abnorm'),
    'leafspots-halo': create_dict('absent,yellow-halos,no-yellow-halos,?'),
    'leafspots-marg': create_dict('w-s-marg,no-w-s-marg,dna,?'),
    'leafspot-size': create_dict('lt-1/8,gt-1/8,dna,?'),
    'leaf-shread': create_dict('absent,present,?'),
    'leaf-malf': create_dict('absent,present,?'),
    'leaf-mild': create_dict('absent,upper-surf,lower-surf,?'),
    'stem': create_dict('norm,abnorm,?'),
    'lodging': create_dict('yes,no,?'),
    'stem-cankers': create_dict('absent,below-soil,above-soil,above-sec-nde,?'),
    'canker-lesion': create_dict('dna,brown,dk-brown-blk,tan,?'),
    'fruiting-bodies': create_dict('absent,present,?'),
    'external decay': create_dict('absent,firm-and-dry,watery,?'),
    'mycelium': create_dict('absent,present,?'),
    'int-discolor': create_dict('none,brown,black,?'),
    'sclerotia': create_dict('absent,present,?'),
    'fruit-pods': create_dict('norm,diseased,few-present,dna,?'),
    'fruit spots': create_dict('absent,colored,brown-w/blk-specks,distort,dna,?'),
    'seed': create_dict('norm,abnorm,?'),
    'mold-growth': create_dict('absent,present,?'),
    'seed-discolor': create_dict('absent,present,?'),
    'seed-size': create_dict('norm,lt-norm,?'),
    'shriveling': create_dict('absent,present,?'),
    'roots': create_dict('norm,rotted,galls-cysts,?')
}

# %%
def get_map_val(key, val):
    if val == '?':
        search_val = '?'
    else:
        search_val = int(val)
        
    return maps.get(key).get(search_val)

for c in maps.keys():
    df[c] = df[c].apply(lambda x: get_map_val(c, x))

# %%
df.head()
# Out:
#                    class     date plant-stand   precip  temp hail  \
# 0  diaporthe-stem-canker  october      normal  gt-norm  norm  yes
# 1  diaporthe-stem-canker   august      normal  gt-norm  norm  yes
# 2  diaporthe-stem-canker     july      normal  gt-norm  norm  yes
# 3  diaporthe-stem-canker     july      normal  gt-norm  norm  yes
# 4  diaporthe-stem-canker  october      normal  gt-norm  norm  yes
#
#           crop-hist area-damaged    severity   seed-tmt  ... int-discolor  \
# 0       same-lst-yr    low-areas  pot-severe       none  ...         none
# 1  same-lst-two-yrs    scattered      severe  fungicide  ...         none
# 2       same-lst-yr    scattered      severe  fungicide  ...         none
# 3       same-lst-yr    scattered      severe       none  ...         none
# 4  same-lst-two-yrs    scattered  pot-severe       none  ...         none
#
#   sclerotia fruit-pods fruit spots  seed mold-growth seed-discolor seed-size  \
# 0    absent       norm         dna  norm      absent        absent      norm
# 1    absent       norm         dna  norm      absent        absent      norm
# 2    absent       norm         dna  norm      absent        absent      norm
# 3    absent       norm         dna  norm      absent        absent      norm
# 4    absent       norm         dna  norm      absent        absent      norm
#
#   shriveling roots
# 0     absent  norm
# 1     absent  norm
# 2     absent  norm
# 3     absent  norm
# 4     absent  norm
#
# [5 rows x 36 columns]

# %% [markdown]
# # 1.2.2 Data cleaning and missing values

# %% [markdown]
# ### Question 1

# %%
def plot_distribution(dataset, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == object:
            g = sns.countplot(y=column, data=dataset)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            g = sns.distplot(dataset[column])
            plt.xticks(rotation=25)

# %%
plot_distribution(df, cols=3, width=20, height=60, hspace=0.6, wspace=0.5)

# %%
#Mold growth and seed discolor are redundant features
#Plant stand and stem seem to be redundant features
#LEave shred and seed also seem to be redundant features

# %% [markdown]
# ### Question 2

# %%
df.isna().sum()
# Out:
# class               0
# date                1
# plant-stand         8
# precip             11
# temp                7
# hail               41
# crop-hist           1
# area-damaged        1
# severity           41
# seed-tmt           41
# germination        36
# plant-growth        1
# leaves              0
# leafspots-halo     25
# leafspots-marg     25
# leafspot-size      25
# leaf-shread        26
# leaf-malf          25
# leaf-mild          30
# stem                1
# lodging            41
# stem-cankers       11
# canker-lesion      11
# fruiting-bodies    35
# external decay     11
# mycelium           11
# int-discolor       11
# sclerotia          11
# fruit-pods         25
# fruit spots        35
# seed               29
# mold-growth        29
# seed-discolor      35
# seed-size          29
# shriveling         35
# roots               7
# dtype: int64

# %% [markdown]
# **hail, severity, seed-tmt and lodging are the feautures with the most missing values**

# %%
null_data = df[df.isnull().any(axis=1)]

# %%
null_data
# Out:
#                            class       date plant-stand   precip     temp  \
# 31              phytophthora-rot        may   lt-normal  gt-norm     norm
# 32              phytophthora-rot       june   lt-normal  gt-norm  gt-norm
# 34              phytophthora-rot       june   lt-normal  gt-norm  gt-norm
# 35              phytophthora-rot       july   lt-normal  gt-norm     norm
# 38              phytophthora-rot       june   lt-normal     norm     norm
# 40              phytophthora-rot       june   lt-normal  gt-norm     norm
# 41              phytophthora-rot        may   lt-normal  gt-norm     norm
# 45              phytophthora-rot       june   lt-normal  gt-norm  gt-norm
# 47              phytophthora-rot       june   lt-normal     norm  gt-norm
# 51              phytophthora-rot        may   lt-normal  gt-norm     norm
# 52              phytophthora-rot       july   lt-normal  gt-norm     norm
# 53              phytophthora-rot       june   lt-normal  gt-norm     norm
# 54              phytophthora-rot       july   lt-normal  gt-norm  gt-norm
# 56              phytophthora-rot       july   lt-normal     norm     norm
# 57              phytophthora-rot       june   lt-normal  gt-norm  gt-norm
# 58              phytophthora-rot       july   lt-normal     norm  gt-norm
# 59              phytophthora-rot        may   lt-normal  gt-norm  gt-norm
# 60              phytophthora-rot       june   lt-normal  gt-norm  gt-norm
# 61              phytophthora-rot       july   lt-normal     norm     norm
# 63              phytophthora-rot       july   lt-normal     norm     norm
# 64              phytophthora-rot       june   lt-normal  gt-norm  gt-norm
# 66              phytophthora-rot       july   lt-normal  gt-norm     norm
# 67              phytophthora-rot       july   lt-normal  gt-norm     norm
# 69              phytophthora-rot       july   lt-normal  gt-norm  gt-norm
# 290  diaporthe-pod-&-stem-blight  september      normal  gt-norm  gt-norm
# 291  diaporthe-pod-&-stem-blight    october      normal  gt-norm  gt-norm
# 292  diaporthe-pod-&-stem-blight  september      normal  gt-norm  gt-norm
# 293  diaporthe-pod-&-stem-blight        may   lt-normal     norm  gt-norm
# 294  diaporthe-pod-&-stem-blight  september        None  gt-norm  gt-norm
# 295  diaporthe-pod-&-stem-blight  september      normal  gt-norm  gt-norm
# 296                cyst-nematode       june        None     None     None
# 297                cyst-nematode       july        None     None     None
# 298                cyst-nematode     august        None     None     None
# 299                cyst-nematode       july        None     None     None
# 300                cyst-nematode       july        None     None     None
# 301                cyst-nematode     august        None     None     None
# 302                 2-4-d-injury       None        None     None     None
# 303             herbicide-injury        may   lt-normal     None  lt-norm
# 304             herbicide-injury      april   lt-normal     None  lt-norm
# 305             herbicide-injury        may   lt-normal     None  lt-norm
# 306             herbicide-injury        may   lt-normal     None  lt-norm
#
#      hail         crop-hist area-damaged severity seed-tmt  ... int-discolor  \
# 31   None  same-lst-sev-yrs    low-areas     None     None  ...         none
# 32   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 34   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 35   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 38   None     diff-lst-year    low-areas     None     None  ...         none
# 40   None       same-lst-yr    low-areas     None     None  ...         none
# 41   None       same-lst-yr    low-areas     None     None  ...         none
# 45   None  same-lst-sev-yrs    low-areas     None     None  ...         none
# 47   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 51   None     diff-lst-year    low-areas     None     None  ...         none
# 52   None       same-lst-yr    low-areas     None     None  ...         none
# 53   None       same-lst-yr    low-areas     None     None  ...         none
# 54   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 56   None  same-lst-sev-yrs    low-areas     None     None  ...         none
# 57   None       same-lst-yr    low-areas     None     None  ...         none
# 58   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 59   None       same-lst-yr    low-areas     None     None  ...         none
# 60   None  same-lst-sev-yrs    low-areas     None     None  ...         none
# 61   None     diff-lst-year    low-areas     None     None  ...         none
# 63   None       same-lst-yr    low-areas     None     None  ...         none
# 64   None       same-lst-yr    low-areas     None     None  ...         none
# 66   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 67   None  same-lst-sev-yrs    low-areas     None     None  ...         none
# 69   None  same-lst-two-yrs    low-areas     None     None  ...         none
# 290  None  same-lst-sev-yrs  whole-field     None     None  ...         none
# 291  None  same-lst-two-yrs  whole-field     None     None  ...         none
# 292  None  same-lst-sev-yrs  whole-field     None     None  ...         none
# 293  None  same-lst-sev-yrs    scattered     None     None  ...         none
# 294  None  same-lst-two-yrs  whole-field     None     None  ...         none
# 295  None  same-lst-two-yrs  whole-field     None     None  ...         none
# 296  None  same-lst-two-yrs    low-areas     None     None  ...         None
# 297  None  same-lst-sev-yrs  upper-areas     None     None  ...         None
# 298  None  same-lst-sev-yrs  upper-areas     None     None  ...         None
# 299  None  same-lst-two-yrs    low-areas     None     None  ...         None
# 300  None  same-lst-two-yrs    low-areas     None     None  ...         None
# 301  None  same-lst-two-yrs    low-areas     None     None  ...         None
# 302  None              None         None     None     None  ...         None
# 303  None       same-lst-yr    scattered     None     None  ...         None
# 304  None     diff-lst-year  whole-field     None     None  ...         None
# 305  None     diff-lst-year    scattered     None     None  ...         None
# 306  None       same-lst-yr  whole-field     None     None  ...         None
#
#     sclerotia   fruit-pods         fruit spots    seed mold-growth  \
# 31     absent         None                None    None        None
# 32     absent         None                None    None        None
# 34     absent         None                None    None        None
# 35     absent         None                None    None        None
# 38     absent         None                None    None        None
# 40     absent         None                None    None        None
# 41     absent         None                None    None        None
# 45     absent         None                None    None        None
# 47     absent         None                None    None        None
# 51     absent         None                None    None        None
# 52     absent         None                None    None        None
# 53     absent         None                None    None        None
# 54     absent         None                None    None        None
# 56     absent         None                None    None        None
# 57     absent         None                None    None        None
# 58     absent         None                None    None        None
# 59     absent         None                None    None        None
# 60     absent         None                None    None        None
# 61     absent         None                None    None        None
# 63     absent         None                None    None        None
# 64     absent         None                None    None        None
# 66     absent         None                None    None        None
# 67     absent         None                None    None        None
# 69     absent         None                None    None        None
# 290    absent     diseased  brown-w/blk-specks    norm     present
# 291    absent     diseased  brown-w/blk-specks  abnorm     present
# 292    absent     diseased  brown-w/blk-specks  abnorm     present
# 293    absent     diseased  brown-w/blk-specks    norm     present
# 294    absent     diseased  brown-w/blk-specks  abnorm     present
# 295    absent     diseased  brown-w/blk-specks  abnorm     present
# 296      None  few-present                None  abnorm      absent
# 297      None  few-present                None  abnorm      absent
# 298      None  few-present                None  abnorm      absent
# 299      None  few-present                None  abnorm      absent
# 300      None  few-present                None  abnorm      absent
# 301      None  few-present                None  abnorm      absent
# 302      None         None                None    None        None
# 303      None          dna                None    None        None
# 304      None          dna                None    None        None
# 305      None          dna                None    None        None
# 306      None          dna                None    None        None
#
#     seed-discolor seed-size shriveling        roots
# 31           None      None       None       rotted
# 32           None      None       None       rotted
# 34           None      None       None       rotted
# 35           None      None       None       rotted
# 38           None      None       None       rotted
# 40           None      None       None       rotted
# 41           None      None       None       rotted
# 45           None      None       None       rotted
# 47           None      None       None       rotted
# 51           None      None       None       rotted
# 52           None      None       None       rotted
# 53           None      None       None       rotted
# 54           None      None       None       rotted
# 56           None      None       None       rotted
# 57           None      None       None       rotted
# 58           None      None       None       rotted
# 59           None      None       None       rotted
# 60           None      None       None       rotted
# 61           None      None       None       rotted
# 63           None      None       None       rotted
# 64           None      None       None       rotted
# 66           None      None       None       rotted
# 67           None      None       None       rotted
# 69           None      None       None       rotted
# 290       present   lt-norm    present         None
# 291       present   lt-norm    present         None
# 292       present   lt-norm    present         None
# 293       present   lt-norm    present         None
# 294       present   lt-norm    present         None
# 295       present   lt-norm    present         None
# 296          None   lt-norm       None  galls-cysts
# 297          None   lt-norm       None  galls-cysts
# 298          None   lt-norm       None  galls-cysts
# 299          None   lt-norm       None  galls-cysts
# 300          None   lt-norm       None  galls-cysts
# 301          None   lt-norm       None  galls-cysts
# 302          None      None       None         None
# 303          None      None       None       rotted
# 304          None      None       None       rotted
# 305          None      None       None       rotted
# 306          None      None       None       rotted
#
# [41 rows x 36 columns]

# %%
plot_distribution(null_data[['class']], cols=3, width=20, height=5, hspace=0.5, wspace=0.5)

# %% [markdown]
# **The class phytophthora has the most missing values**

# %% [markdown]
# ### Question 3

# %%
null_classes = np.unique(null_data[['class']])
print(f'Original number of  data points for the classes with missing values\n {df.loc[df["class"].isin(null_classes)]["class"].value_counts()}')
# Out:
# Original number of  data points for the classes with missing values
#  phytophthora-rot               40
# diaporthe-pod-&-stem-blight     6
# cyst-nematode                   6
# herbicide-injury                4
# 2-4-d-injury                    1
# Name: class, dtype: int64

# %%
perc_null = np.round(null_data.isnull().sum(axis = 1)/len(null_data.columns),decimals=2)*100
null_counts = pd.concat([null_data['class'],null_data.isnull().sum(axis = 1),perc_null],ignore_index=True,axis=1)
null_counts.columns =['class','No. of features N/A','Percent of features N/A']
null_counts
# Out:
#                            class  No. of features N/A  Percent of features N/A
# 31              phytophthora-rot                   13                     36.0
# 32              phytophthora-rot                   19                     53.0
# 34              phytophthora-rot                   19                     53.0
# 35              phytophthora-rot                   19                     53.0
# 38              phytophthora-rot                   13                     36.0
# 40              phytophthora-rot                   13                     36.0
# 41              phytophthora-rot                   19                     53.0
# 45              phytophthora-rot                   19                     53.0
# 47              phytophthora-rot                   13                     36.0
# 51              phytophthora-rot                   13                     36.0
# 52              phytophthora-rot                   19                     53.0
# 53              phytophthora-rot                   13                     36.0
# 54              phytophthora-rot                   19                     53.0
# 56              phytophthora-rot                   13                     36.0
# 57              phytophthora-rot                   19                     53.0
# 58              phytophthora-rot                   13                     36.0
# 59              phytophthora-rot                   19                     53.0
# 60              phytophthora-rot                   13                     36.0
# 61              phytophthora-rot                   13                     36.0
# 63              phytophthora-rot                   13                     36.0
# 64              phytophthora-rot                   19                     53.0
# 66              phytophthora-rot                   19                     53.0
# 67              phytophthora-rot                   19                     53.0
# 69              phytophthora-rot                   19                     53.0
# 290  diaporthe-pod-&-stem-blight                   11                     31.0
# 291  diaporthe-pod-&-stem-blight                   11                     31.0
# 292  diaporthe-pod-&-stem-blight                   11                     31.0
# 293  diaporthe-pod-&-stem-blight                   11                     31.0
# 294  diaporthe-pod-&-stem-blight                   13                     36.0
# 295  diaporthe-pod-&-stem-blight                   11                     31.0
# 296                cyst-nematode                   24                     67.0
# 297                cyst-nematode                   24                     67.0
# 298                cyst-nematode                   24                     67.0
# 299                cyst-nematode                   24                     67.0
# 300                cyst-nematode                   24                     67.0
# 301                cyst-nematode                   24                     67.0
# 302                 2-4-d-injury                   30                     83.0
# 303             herbicide-injury                   20                     56.0
# 304             herbicide-injury                   20                     56.0
# 305             herbicide-injury                   20                     56.0
# 306             herbicide-injury                   20                     56.0

# %%
# How much data would we lose?
df.shape
# Out:
# (307, 36)

# %% [markdown]
# **Since it is meantioned that the classes cyst-nematode, 2-4-d-injury, herbicide-injury are unjustified by the data and also have more than 50% of their features having missing values we can remove the data points from the dataset.**

# %%
# Find index of rows to be dropped
cols_to_drop = ['cyst-nematode', '2-4-d-injury', 'herbicide-injury']
indices_to_drop = df[df['class'].isin(cols_to_drop) ].index

# How much data would we lose?
print(f'We are removing {len(df[df["class"].isin(cols_to_drop) ])} data points from the data set')

# Percentage of data lost
print( f'{np.round(len(df[df["class"].isin(cols_to_drop) ])/df.shape[0],2)*100}% is close to the recommended 3%' )

# Drop rows
df = df.drop(indices_to_drop)
# Out:
# We are removing 11 data points from the data set
# 4.0% is close to the recommended 3%

# %% [markdown]
# **Elimination of phytophthora-rot would be eliminating about 50% of the data points for the case of phytophthora-rot.**
